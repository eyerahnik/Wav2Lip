# %% [markdown]
# <a href="https://colab.research.google.com/github/eyerahnik/Wav2Lip/blob/master/ollama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install zstd and Ollama
# !sudo apt-get update && sudo apt-get install zstd -y
# !curl -fsSL https://ollama.com/install.sh | sh

# 2. Start Ollama in the background
import os
import subprocess
import time

# Set OLLAMA_ORIGINS="*" so Zo AI Computer can talk to it
os.environ['OLLAMA_ORIGINS'] = "*"

# Start the server
subprocess.Popen(['ollama', 'serve'])

# Give it a second to wake up
time.sleep(5)

# 3. Pull a Tool-Capable model (like Qwen 2.5 Coder 7B)
# This model will actually work with Zo's agent features
# !ollama pull qwen2.5-coder:7b
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.8 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,328 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,678 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# ...

# %%
# Start the server
subprocess.Popen(['ollama', 'serve'])
# Out:
# <Popen: returncode: None args: ['ollama', 'serve']>

# %%
# 1. Install the missing hardware detection tool
# !sudo apt-get install -y pciutils

# 2. Kill any "stray" Ollama processes and start fresh
# !pkill ollama
import os
import subprocess
import time

# Essential: Set OLLAMA_ORIGINS to let Zo talk to it
os.environ['OLLAMA_ORIGINS'] = "*"

# Start Ollama server in the background
subprocess.Popen(['ollama', 'serve'])

# Wait for it to wake up
time.sleep(5)

# 3. VERIFY: This should show your Tesla T4 GPU
# !ollama list
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids
# The following NEW packages will be installed:
#   libpci3 pci.ids pciutils
# 0 upgraded, 3 newly installed, 0 to remove and 110 not upgraded.
# Need to get 343 kB of archives.
# After this operation, 1,581 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Fetched 343 kB in 1s (596 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# ...

# %%
# !ollama pull qwen2.5-coder:14b

# %%
# !ollama pull qwen2.5-coder:14b

# %%
# Run this in a new cell to pull the model properly
import subprocess

model_name = "qwen2.5-coder:14b"
print(f"Starting pull for {model_name}... This will take 3-5 minutes.")

process = subprocess.Popen(['ollama', 'pull', model_name],
                           stdout=subprocess.PIPE,
                           stderr=subprocess.STDOUT,
                           text=True)

for line in process.stdout:
    print(line, end='')
# Out:
# Starting pull for qwen2.5-coder:14b... This will take 3-5 minutes.
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling ac9bc7a69dab: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling 1e65450c3067: 100% ▕██████████████████▏ 1.6 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling 0578f229f23a: 100% ▕██████████████████▏  488 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Install ngrok (you'll need your authtoken)
# !pip install pyngrok

# Authenticate ngrok (replace with your actual token)
from pyngrok import ngrok
# ngrok.set_auth_token("ak_392ugPjEIe3alo4RoLAYvav8Dnt")

# Create tunnel to ollama's port (11434)
public_url = ngrok.connect(11434)
print(f"Your ollama endpoint: {public_url}")
# Out:
# ...
# ERROR:pyngrok.process.ngrok:t=2026-02-01T02:06:04+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-02-01T02:06:04+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipython-input-3913574889.py in <cell line: 0>()
#       7
# ...

# %%
ngrok config add-authtoken 392oTUraq7pgYOIts56YYrTBv1U_38FUCFWboKZm2tkmhn8S3
# Out:
#   File "/tmp/ipython-input-300686803.py", line 1
#     ngrok config add-authtoken 392oTUraq7pgYOIts56YYrTBv1U_38FUCFWboKZm2tkmhn8S3
#                                  ^
# SyntaxError: invalid decimal literal

# %%
# Install ngrok
# !pip install pyngrok

# Configure with your token
from pyngrok import ngrok
ngrok.set_auth_token("392oTUraq7pgYOIts56YYrTBv1U_38FUCFWboKZm2tkmhn8S3")

# Install and start ollama
# !curl -fsSL https://ollama.com/install.sh | sh
# !nohup ollama serve > ollama.log 2>&1 &
# !sleep 5

# Verify your model is available
# !ollama list

# Start ngrok tunnel to ollama's port (11434)
public_url = ngrok.connect(11434)
print(f"Your ollama endpoint: {public_url}")
print(f"\nCopy this URL and add it to Zo at [Settings > AI > Providers](/?t=settings&s=your-ai&d=providers)")
print(f"Use port: 11434")
print(f"Model name: qwen2.5-coder:14b")
# Out:
# ...
# >>> Installing ollama to /usr/local
# ERROR: This version requires zstd for extraction. Please install zstd and try again:
#   - Debian/Ubuntu: sudo apt-get install zstd
#   - RHEL/CentOS/Fedora: sudo dnf install zstd
#   - Arch: sudo pacman -S zstd
# /bin/bash: line 1: ollama: command not found
# WARNING:pyngrok.process.ngrok:t=2026-02-01T02:08:58+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=d1aafd0ae118ef4b err="failed to start tunnel: The endpoint 'https://harmonizable-superfluous-millard.ngrok-free.dev' is already online. Either\n1. stop your existing endpoint first, or\n2. start both endpoints with `--pooling-enabled` to load balance between them.\r\n\r\nERR_NGROK_334\r\n"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     573     try:
# ...

# %%
from pyngrok import ngrok
ngrok.set_auth_token("392oTUraq7pgYOIts56YYrTBv1U_38FUCFWboKZm2tkmhn8S3")

# Connect with pooling enabled
public_url = ngrok.connect(11434, options={"pooling_enabled": "true"})
print(f"Your Colab ollama endpoint: {public_url}")
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-02-01T02:12:55+0000 lvl=warn msg="invalid tunnel configuration" pg=/api/tunnels id=284450048014fdf8 err="yaml: unmarshal errors:\n  line 1: field options not found in type config.HTTPv2Tunnel"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     573     try:
# --> 574         response = urlopen(request, encoded_data, timeout)
#     575         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
# ...

# %%
# Install/configure ngrok
from pyngrok import ngrok
ngrok.set_auth_token("392oTUraq7pgYOIts56YYrTBv1U_38FUCFWboKZm2tkmhn8S3")

# Install ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# Start ollama on a DIFFERENT port (e.g., 11435 instead of 11434)
# !OLLAMA_HOST=0.0.0.0:11435 nohup ollama serve > ollama.log 2>&1 &
# !sleep 5

# Verify your model is available
# !OLLAMA_HOST=127.0.0.1:11435 ollama list

# Create ngrok tunnel on the new port
public_url = ngrok.connect(11435)
print(f"Your Colab ollama endpoint: {public_url}")
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# ERROR: This version requires zstd for extraction. Please install zstd and try again:
#   - Debian/Ubuntu: sudo apt-get install zstd
#   - RHEL/CentOS/Fedora: sudo dnf install zstd
#   - Arch: sudo pacman -S zstd
# /bin/bash: line 1: ollama: command not found
# WARNING:pyngrok.process.ngrok:t=2026-02-01T02:13:43+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=4f32957b1095322e err="failed to start tunnel: The endpoint 'https://harmonizable-superfluous-millard.ngrok-free.dev' is already online. Either\n1. stop your existing endpoint first, or\n2. start both endpoints with `--pooling-enabled` to load balance between them.\r\n\r\nERR_NGROK_334\r\n"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ...

# %%
# Run this in a new cell to pull the model properly
import subprocess

model_name = "qwen2.5-coder:14b"
print(f"Starting pull for {model_name}... This will take 3-5 minutes.")

process = subprocess.Popen(['ollama', 'pull', model_name],
                           stdout=subprocess.PIPE,
                           stderr=subprocess.STDOUT,
                           text=True)

for line in process.stdout:
    print(line, end='')
# Out:
# Starting pull for qwen2.5-coder:14b... This will take 3-5 minutes.
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling ac9bc7a69dab: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling 1e65450c3067: 100% ▕██████████████████▏ 1.6 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling 0578f229f23a: 100% ▕██████████████████▏  488 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama serve
# Out:
#   File "/tmp/ipython-input-2189434629.py", line 1
#     ollama serve
#            ^
# SyntaxError: invalid syntax

# %%
# Install/configure ngrok
from pyngrok import ngrok
ngrok.set_auth_token("392oTUraq7pgYOIts56YYrTBv1U_38FUCFWboKZm2tkmhn8S3")

# Install ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# Start ollama on a DIFFERENT port (e.g., 11435 instead of 11434)
# !OLLAMA_HOST=0.0.0.0:11435 nohup ollama serve > ollama.log 2>&1 &
# !sleep 5

# Verify your model is available
# !OLLAMA_HOST=127.0.0.1:11435 ollama list

# Create ngrok tunnel on the new port
public_url = ngrok.connect(11435)
print(f"Your Colab ollama endpoint: {public_url}")
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# ERROR: This version requires zstd for extraction. Please install zstd and try again:
#   - Debian/Ubuntu: sudo apt-get install zstd
#   - RHEL/CentOS/Fedora: sudo dnf install zstd
#   - Arch: sudo pacman -S zstd
# /bin/bash: line 1: ollama: command not found
# WARNING:pyngrok.process.ngrok:t=2026-02-01T02:14:35+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=de92fcd70613e766 err="failed to start tunnel: The endpoint 'https://harmonizable-superfluous-millard.ngrok-free.dev' is already online. Either\n1. stop your existing endpoint first, or\n2. start both endpoints with `--pooling-enabled` to load balance between them.\r\n\r\nERR_NGROK_334\r\n"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ...

# %%
# Install zstd
# !apt-get install -y zstd

# Install ngrok
# !pip install pyngrok

# Install ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# Configure ngrok
from pyngrok import ngrok
ngrok.set_auth_token("392oTUraq7pgYOIts56YYrTBv1U_38FUCFWboKZm2tkmhn8S3")

# Start ollama on port 11435 (different from your local 11434)
# !OLLAMA_HOST=0.0.0.0:11435 nohup ollama serve > ollama.log 2>&1 &
# !sleep 5

# Check ollama logs to make sure it started
# !tail ollama.log

# Verify your model is available
# !OLLAMA_HOST=127.0.0.1:11435 ollama list

# Create ngrok tunnel on port 11435
public_url = ngrok.connect(11435)
print(f"\n=== Your Colab ollama endpoint ===")
print(f"{public_url}")
print(f"\nAdd this URL in Zo as a new provider (different from your local one)")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 1s (454 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# ...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ...

# %%
from pyngrok import ngrok
ngrok.set_auth_token("392oTUraq7pgYOIts56YYrTBv1U_38FUCFWboKZm2tkmhn8S3")

# This will now work since your local tunnel is stopped
public_url = ngrok.connect(11435)
print(f"Colab ollama endpoint: {public_url}")
# Out:
# Colab ollama endpoint: NgrokTunnel: "https://harmonizable-superfluous-millard.ngrok-free.dev" -> "http://localhost:11435"

# %%
# Pull the model (this will take a few minutes)
# !OLLAMA_HOST=127.0.0.1:11435 ollama pull qwen2.5-coder:14b

# Verify it's there
# !OLLAMA_HOST=127.0.0.1:11435 ollama list
# Out:
# NAME                 ID              SIZE      MODIFIED
# qwen2.5-coder:14b    9ec8897f747e    9.0 GB    Less than a second ago

# %%
# Verify ollama can see the model
# !curl http://127.0.0.1:11435/api/tags
# Out:
# {"models":[{"name":"qwen2.5-coder:14b","model":"qwen2.5-coder:14b","modified_at":"2026-02-01T02:42:53.424528674Z","size":8988124298,"digest":"9ec8897f747e246e970bc5cfdda85d22f1123dc2e3d34978a010a75968716849","details":{"parent_model":"","format":"gguf","family":"qwen2","families":["qwen2"],"parameter_size":"14.8B","quantization_level":"Q4_K_M"}}]}

# %%
ollama serve
# Out:
#   File "/tmp/ipython-input-2189434629.py", line 1
#     ollama serve
#            ^
# SyntaxError: invalid syntax

# %%
from pyngrok import ngrok
ngrok.set_auth_token("392oTUraq7pgYOIts56YYrTBv1U_38FUCFWboKZm2tkmhn8S3")

# Make sure ollama is still running on port 11435
# !OLLAMA_HOST=0.0.0.0:11435 nohup ollama serve > ollama.log 2>&1 &
# !sleep 3

# Check if ollama is responding
# !curl http://127.0.0.1:11435/api/tags

# Start new ngrok tunnel
public_url = ngrok.connect(11435)
print(f"\n=== Your new Colab ollama endpoint ===")
print(f"{public_url}")
# Out:
# {"models":[{"name":"qwen2.5-coder:14b","model":"qwen2.5-coder:14b","modified_at":"2026-02-01T02:42:53.424528674Z","size":8988124298,"digest":"9ec8897f747e246e970bc5cfdda85d22f1123dc2e3d34978a010a75968716849","details":{"parent_model":"","format":"gguf","family":"qwen2","families":["qwen2"],"parameter_size":"14.8B","quantization_level":"Q4_K_M"}}]}
# === Your new Colab ollama endpoint ===
# NgrokTunnel: "https://harmonizable-superfluous-millard.ngrok-free.dev" -> "http://localhost:11435"

# %%
import time

def keep_awake(interval=900):  # interval in seconds
    while True:
        time.sleep(interval)
        IPython.display.clear_output(wait=True)

keep_awake()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1809820530.py in <cell line: 0>()
#       6         IPython.display.clear_output(wait=True)
#       7
# ----> 8 keep_awake()
#
# /tmp/ipython-input-1809820530.py in keep_awake(interval)
#       4     while True:
#       5         time.sleep(interval)
# ----> 6         IPython.display.clear_output(wait=True)
#       7
#       8 keep_awake()
#
# NameError: name 'IPython' is not defined
